# %%
# Import packages
import pandas as pd

# %%
# scrape the list of S&P 500
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
payload = pd.read_html(url)
symbol_list = payload[0]

# %%
symbol_list
# Out:
#     Symbol       Security SEC filings             GICS Sector  \
# 0      MMM             3M     reports             Industrials
# 1      AOS    A. O. Smith     reports             Industrials
# 2      ABT         Abbott     reports             Health Care
# 3     ABBV         AbbVie     reports             Health Care
# 4     ABMD        Abiomed     reports             Health Care
# ..     ...            ...         ...                     ...
# 499    YUM    Yum! Brands     reports  Consumer Discretionary
# 500   ZBRA          Zebra     reports  Information Technology
# 501    ZBH  Zimmer Biomet     reports             Health Care
# 502   ZION  Zions Bancorp     reports              Financials
# 503    ZTS         Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 499                         Restaurants     Louisville, Kentucky
# 500  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 501               Health Care Equipment          Warsaw, Indiana
# 502                      Regional Banks     Salt Lake City, Utah
# 503                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 499       1997-10-06  1041061         1997
# 500       2019-12-23   877212         1969
# 501       2001-08-07  1136869         1927
# 502       2001-06-22   109380         1873
# 503       2013-06-21  1555280         1952
#
# [504 rows x 9 columns]

# %%
# save to local csv file
symbol_list.to_csv('S&P500_symbol_list.csv', index=False)

# %%
# import MongoClient from pymongo
from pymongo import MongoClient

# establish a client connection
MONGODB_CONNECTION_STRING = "<Your Connection String Here>"
client = MongoClient(MONGODB_CONNECTION_STRING)

# %%
# to check if connection has been established
client.server_info()['ok']
# Out:
# 1.0

# %%
# convert to dictionary for uploading to MongoDB
symbol_dict = symbol_list.to_dict('records')

# point to symbolsDB collection 
db = client.symbolsDB

# emtpy symbols collection before inserting new records
db.symbols.drop()

# insert new symbols
db.symbols.insert_many(symbol_dict)

# %%
# get all records from collection
symbol_list_from_DB = db.symbols.find({ })
pd.DataFrame(list(symbol_list_from_DB))
# Out:
#                           _id Symbol       Security SEC filings  \
# 0    625bafeef354d059c849fa6c    MMM             3M     reports
# 1    625bafeef354d059c849fa6d    AOS    A. O. Smith     reports
# 2    625bafeef354d059c849fa6e    ABT         Abbott     reports
# 3    625bafeef354d059c849fa6f   ABBV         AbbVie     reports
# 4    625bafeef354d059c849fa70   ABMD        Abiomed     reports
# ..                        ...    ...            ...         ...
# 499  625bafeef354d059c849fc5f    YUM    Yum! Brands     reports
# 500  625bafeef354d059c849fc60   ZBRA          Zebra     reports
# 501  625bafeef354d059c849fc61    ZBH  Zimmer Biomet     reports
# 502  625bafeef354d059c849fc62   ZION  Zions Bancorp     reports
# 503  625bafeef354d059c849fc63    ZTS         Zoetis     reports
#
#                 GICS Sector                   GICS Sub-Industry  \
# 0               Industrials            Industrial Conglomerates
# 1               Industrials                   Building Products
# 2               Health Care               Health Care Equipment
# 3               Health Care                     Pharmaceuticals
# 4               Health Care               Health Care Equipment
# ..                      ...                                 ...
# 499  Consumer Discretionary                         Restaurants
# 500  Information Technology  Electronic Equipment & Instruments
# 501             Health Care               Health Care Equipment
# 502              Financials                      Regional Banks
# 503             Health Care                     Pharmaceuticals
#
#        Headquarters Location Date first added      CIK      Founded
# 0      Saint Paul, Minnesota       1976-08-09    66740         1902
# 1       Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2    North Chicago, Illinois       1964-03-31     1800         1888
# 3    North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4     Danvers, Massachusetts       2018-05-31   815094         1981
# ..                       ...              ...      ...          ...
# 499     Louisville, Kentucky       1997-10-06  1041061         1997
# 500   Lincolnshire, Illinois       2019-12-23   877212         1969
# 501          Warsaw, Indiana       2001-08-07  1136869         1927
# 502     Salt Lake City, Utah       2001-06-22   109380         1873
# 503   Parsippany, New Jersey       2013-06-21  1555280         1952
#
# [504 rows x 10 columns]
